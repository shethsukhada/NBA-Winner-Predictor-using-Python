# %%
#Decision Trees and Random Forests
#Sukhada Sheth 

#Decision Trees - Classification Alogorith in Supervised Learning which can work with variety of features including 
#                  Categorical features
#Random Forest  - Can be further used to improve upon Decision trees

#Data Source - https://www.basketball-reference.com/leagues/NBA_2016_games.html

# %% [markdown]
# # Predicting the winner of games of the National Basketball Association(NBA)

# %%
import pandas as pd

data_filename = "basketball.csv"
dataset = pd.read_csv(data_filename)

dataset.head() #print top 5 rows
# Out:
#               Date Start (ET)       Visitor/Neutral  PTS  \
# 0  Tue Oct 27 2015      8:00p       Detroit Pistons  106
# 1  Tue Oct 27 2015      8:00p   Cleveland Cavaliers   95
# 2  Tue Oct 27 2015     10:30p  New Orleans Pelicans   95
# 3  Wed Oct 28 2015      7:30p    Philadelphia 76ers   95
# 4  Wed Oct 28 2015      7:30p         Chicago Bulls  115
#
#             Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend. Notes
# 0          Atlanta Hawks     94  Box Score        NaN    19187   NaN
# 1          Chicago Bulls     97  Box Score        NaN    21957   NaN
# 2  Golden State Warriors    111  Box Score        NaN    19596   NaN
# 3         Boston Celtics    112  Box Score        NaN    18624   NaN
# 4          Brooklyn Nets    100  Box Score        NaN    17732   NaN

# %%
#format the date column
dataset = pd.read_csv(data_filename, parse_dates=["Date"])
#label the columns of the dataset
dataset.columns = ["Date", "Start (ET)", "Visitor Team", "VisitorPts", "Home Team", "HomePts", "OT?", "Score Type", "Attend.", "Notes"]

dataset.head() #print top 5 rows
# Out:
#         Date Start (ET)          Visitor Team  VisitorPts  \
# 0 2015-10-27      8:00p       Detroit Pistons         106
# 1 2015-10-27      8:00p   Cleveland Cavaliers          95
# 2 2015-10-27     10:30p  New Orleans Pelicans          95
# 3 2015-10-28      7:30p    Philadelphia 76ers          95
# 4 2015-10-28      7:30p         Chicago Bulls         115
#
#                Home Team  HomePts        OT? Score Type  Attend. Notes
# 0          Atlanta Hawks       94  Box Score        NaN    19187   NaN
# 1          Chicago Bulls       97  Box Score        NaN    21957   NaN
# 2  Golden State Warriors      111  Box Score        NaN    19596   NaN
# 3         Boston Celtics      112  Box Score        NaN    18624   NaN
# 4          Brooklyn Nets      100  Box Score        NaN    17732   NaN

# %%
print(dataset.dtypes) #print datatype of each column of dataset

dataset["HomeWin"] = dataset["VisitorPts"] < dataset["HomePts"]  #add new feature/column depending on who has more points

dataset.head()
# Out:
# Date            datetime64[ns]
# Start (ET)              object
# Visitor Team            object
# VisitorPts               int64
# Home Team               object
# HomePts                  int64
# OT?                     object
# Score Type              object
# Attend.                  int64
# Notes                   object
# dtype: object
#         Date Start (ET)          Visitor Team  VisitorPts  \
# 0 2015-10-27      8:00p       Detroit Pistons         106
# 1 2015-10-27      8:00p   Cleveland Cavaliers          95
# 2 2015-10-27     10:30p  New Orleans Pelicans          95
# 3 2015-10-28      7:30p    Philadelphia 76ers          95
# 4 2015-10-28      7:30p         Chicago Bulls         115
#
#                Home Team  HomePts        OT? Score Type  Attend. Notes  \
# 0          Atlanta Hawks       94  Box Score        NaN    19187   NaN
# 1          Chicago Bulls       97  Box Score        NaN    21957   NaN
# 2  Golden State Warriors      111  Box Score        NaN    19596   NaN
# 3         Boston Celtics      112  Box Score        NaN    18624   NaN
# 4          Brooklyn Nets      100  Box Score        NaN    17732   NaN
#
#    HomeWin
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False

# %%
#creating a class array for later to be used in scikit-learn
y_true = dataset["HomeWin"].values #create list of class for homewinner
print(type(y_true))

dataset["HomeWin"].mean()  #mean of homewinner chances

print(y_true[0:5])
# Out:
# <class 'numpy.ndarray'>
# [False  True  True  True False]

# %% [markdown]
# Now here we cannot use the game points to train the model becuase for the new game we would not know the points before the game happens. Hence creating new features which can be used to train the model
#
# First new feature - 1.which team had won the previous game

# %%
from collections import defaultdict
won_last = defaultdict(int)   #will use this dictionary to hold the previous game result.
#key - team name and value - won/last previous game

#create two new columns which would hold value of result of previous game
dataset["HomeLastWin"] = 0  
dataset["VisitorLastWin"] = 0

# %%
#for each row , update the winner of previous game 

#for index, row in enumerate(dataset):
for index, row in dataset.sort_values("Date").iterrows():
    home_team = row["Home Team"]
    visitor_team = row["Visitor Team"]
    row["HomeLastWin"] = won_last[home_team]
    dataset.at[index, "HomeLastWin"] = won_last[home_team]
    dataset.at[index, "VisitorLastWin"] =  won_last[visitor_team]
#also, update the won_last depending upon the current row data
    won_last[home_team] = int(row["HomeWin"])
    won_last[visitor_team] = 1 - int(row["HomeWin"])
    
dataset.tail(10)

#this entire process would set the valu 1 or 0 for home team and visitor team indicating if those team had won their
#previous game. At this moment we are only checking if team had won or not, we are not considering if it had won or lost
#against the same opponent
# Out:
#            Date Start (ET)           Visitor Team  VisitorPts  \
# 1306 2016-05-27      8:30p    Cleveland Cavaliers         113
# 1307 2016-05-28      9:00p  Golden State Warriors         108
# 1308 2016-05-30      9:00p  Oklahoma City Thunder          88
# 1309 2016-06-02      9:00p    Cleveland Cavaliers          89
# 1310 2016-06-05      8:00p    Cleveland Cavaliers          77
# 1311 2016-06-08      9:00p  Golden State Warriors          90
# 1312 2016-06-10      9:00p  Golden State Warriors         108
# 1313 2016-06-13      9:00p    Cleveland Cavaliers         112
# 1314 2016-06-16      9:00p  Golden State Warriors         101
# 1315 2016-06-19      8:00p    Cleveland Cavaliers          93
#
#                   Home Team  HomePts        OT? Score Type  Attend. Notes  \
# 1306        Toronto Raptors       87  Box Score        NaN    20605   NaN
# 1307  Oklahoma City Thunder      101  Box Score        NaN    18203   NaN
# 1308  Golden State Warriors       96  Box Score        NaN    19596   NaN
# 1309  Golden State Warriors      104  Box Score        NaN    19596   NaN
# 1310  Golden State Warriors      110  Box Score        NaN    19596   NaN
# 1311    Cleveland Cavaliers      120  Box Score        NaN    20562   NaN
# 1312    Cleveland Cavaliers       97  Box Score        NaN    20562   NaN
# 1313  Golden State Warriors       97  Box Score        NaN    19596   NaN
# 1314    Cleveland Cavaliers      115  Box Score        NaN    20562   NaN
# 1315  Golden State Warriors       89  Box Score        NaN    19596   NaN
#
#       HomeWin  HomeLastWin  VisitorLastWin
# 1306    False            0               1
# 1307    False            0               1
# 1308     True            1               0
# 1309     True            1               1
# 1310     True            1               0
# 1311     True            0               1
# 1312    False            1               0
# 1313    False            1               0
# 1314     True            1               0
# 1315    False            0               1

# %%
dataset.iloc[1000:1005]

#create numpy array 
X_previouswins = dataset[["HomeLastWin", "VisitorLastWin"]].values
print(type(X_previouswins))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Will use Decision Tree algorithm implementation of sklearn library which uses Classification and Regression Trees(CART)

# %%
####################decision tree application starts ##################

from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=14)

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

scores = cross_val_score(clf, X_previouswins, y_true,scoring='accuracy',cv=3)
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 59.4%

# %% [markdown]
# Now here the score is just 59.4 which is almost same as average of number of times home team has won
# which we calculated in previous steps. Hence we need to improve this. One of the way is feature engineering.

# %% [markdown]
# So for feature engineering considering two new questions :
#    1.  which team is considered better generally - we will use standings(rankings) to decide this. New set of data is pulled from https://www.basketball-reference.com/leagues/NBA_2015_standings.html
#    2. which team won their last encounter

# %%
#testing with different feature
import os
standings_filename = os.path.join("standings.csv")

standings = pd.read_csv(standings_filename, skiprows=1)

standings.head()

# %% [markdown]
# Code to add new feature discussed above. which team is considered better generally

# %%
dataset["HomeTeamRanksHigher"] = 0
for index, row in dataset.iterrows():
    home_team = row["Home Team"]
    visitor_team = row["Visitor Team"]
    home_rank = standings[standings["Team"] == home_team]["Rk"].values[0]
    visitor_rank = standings[standings["Team"] == visitor_team]["Rk"].values[0]
    dataset.at[index, "HomeTeamRanksHigher"] =  int(home_rank < visitor_rank)
    
X_homehigher = dataset[[ "HomeTeamRanksHigher", "HomeLastWin", "VisitorLastWin",]].values

# %%
clf = DecisionTreeClassifier(random_state=14, criterion="entropy")

scores = cross_val_score(clf, X_homehigher, y_true, scoring='accuracy',cv=3)

print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 60.9%

# %% [markdown]
# By adding additional feature of which team is standing higher in the rank has gained us little more improvement.
# Will try to imrpove it even further by adding yet another feature. Who won in the last encounter

# %%
last_match_winner = defaultdict(int) #will hold pair of playing teams as a tuple
dataset["HomeTeamWonLast"] = 0 

for index, row in dataset.iterrows():
    home_team = row["Home Team"]
    visitor_team = row["Visitor Team"]
    
    teams = tuple(sorted([home_team, visitor_team]))  # Sort for a consistent ordering

    # Set in the row, who won the last encounter
    home_team_won_last = 1 if last_match_winner[teams] == row["Home Team"] else 0
    dataset.at[index, "HomeTeamWonLast"] =  home_team_won_last
    # Who won this one?
    winner = row["Home Team"] if row["HomeWin"] else row["Visitor Team"]
    last_match_winner[teams] = winner

# %%
dataset.loc[400:450]
# Out:
#           Date Start (ET)            Visitor Team  VisitorPts  \
# 400 2015-12-19      5:00p      Los Angeles Lakers          78
# 401 2015-12-19      7:00p       Charlotte Hornets         101
# 402 2015-12-20      1:00p  Minnesota Timberwolves         100
# 403 2015-12-20      3:30p      Philadelphia 76ers          86
# 404 2015-12-20      8:00p    New Orleans Pelicans         130
# 405 2015-12-20      1:00p  Portland Trail Blazers         109
# 406 2015-12-20      6:00p           Atlanta Hawks         103
# 407 2015-12-20      5:00p         Milwaukee Bucks         101
# 408 2015-12-20      6:00p        Sacramento Kings         104
# 409 2015-12-21      8:00p  Portland Trail Blazers          97
# 410 2015-12-21      7:30p  Minnesota Timberwolves          99
# 411 2015-12-21      8:00p           Brooklyn Nets         105
# 412 2015-12-21      8:00p       Charlotte Hornets          95
# 413 2015-12-21     10:30p   Oklahoma City Thunder         100
# 414 2015-12-21      7:30p           Orlando Magic         107
# 415 2015-12-21      8:30p          Indiana Pacers          92
# 416 2015-12-21      9:00p            Phoenix Suns          89
# 417 2015-12-21      7:00p        Sacramento Kings          99
# 418 2015-12-22      9:00p      Los Angeles Lakers         111
# 419 2015-12-22      7:30p         Detroit Pistons          93
# 420 2015-12-22      7:00p       Memphis Grizzlies         104
# 421 2015-12-22      7:30p        Dallas Mavericks          99
# 422 2015-12-23      8:00p         Detroit Pistons         100
# 423 2015-12-23      7:30p        Dallas Mavericks         119
# 424 2015-12-23      7:00p          Boston Celtics         102
# 425 2015-12-23      7:00p         New York Knicks          84
# 426 2015-12-23     10:30p               Utah Jazz          85
# 427 2015-12-23      7:00p        Sacramento Kings         108
# 428 2015-12-23     10:30p   Oklahoma City Thunder         120
# 429 2015-12-23      8:00p      Philadelphia 76ers         100
# 430 2015-12-23      8:00p       San Antonio Spurs         108
# 431 2015-12-23      8:00p  Portland Trail Blazers          89
# 432 2015-12-23      7:00p         Houston Rockets         101
# 433 2015-12-23      9:00p          Denver Nuggets         104
# 434 2015-12-23      7:00p       Memphis Grizzlies          91
# 435 2015-12-25      5:00p     Cleveland Cavaliers          83
# 436 2015-12-25      8:00p       San Antonio Spurs          84
# 437 2015-12-25     10:30p    Los Angeles Clippers          94
# 438 2015-12-25     12:00p    New Orleans Pelicans          88
# 439 2015-12-25      2:30p           Chicago Bulls         105
# 440 2015-12-26      7:30p         New York Knicks          98
# 441 2015-12-26      4:00p      Washington Wizards         111
# 442 2015-12-26      7:00p       Memphis Grizzlies          92
# 443 2015-12-26      8:30p           Chicago Bulls         111
# 444 2015-12-26      7:30p          Boston Celtics          99
# 445 2015-12-26      5:00p         Toronto Raptors         111
# 446 2015-12-26      8:00p          Indiana Pacers         102
# 447 2015-12-26      7:00p         Houston Rockets         108
# 448 2015-12-26      7:00p              Miami Heat         108
# 449 2015-12-26      9:00p      Philadelphia 76ers         111
# 450 2015-12-26     10:00p     Cleveland Cavaliers          76
#
#                   Home Team  HomePts        OT? Score Type  Attend. Notes  \
# 400   Oklahoma City Thunder      118  Box Score        NaN    18203   NaN
# 401      Washington Wizards      109  Box Score        NaN    16987   NaN
# 402           Brooklyn Nets       85  Box Score        NaN    14552   NaN
# 403     Cleveland Cavaliers      108  Box Score        NaN    20562   NaN
# 404          Denver Nuggets      125  Box Score        NaN    13857   NaN
# 405              Miami Heat      116  Box Score        NaN    19600   NaN
# 406           Orlando Magic      100  Box Score        NaN    16982   NaN
# 407            Phoenix Suns       95  Box Score        NaN    16859   NaN
# 408         Toronto Raptors       94  Box Score        NaN    19800   NaN
# 409           Atlanta Hawks      106  Box Score        NaN    18373   NaN
# 410          Boston Celtics      113  Box Score        NaN    18624   NaN
# 411           Chicago Bulls      102  Box Score        NaN    21825   NaN
# 412         Houston Rockets      102  Box Score        NaN    18236   NaN
# 413    Los Angeles Clippers       99  Box Score        NaN    19415   NaN
# 414         New York Knicks       99  Box Score        NaN    19812   NaN
# 415       San Antonio Spurs      106  Box Score        NaN    18418   NaN
# 416               Utah Jazz      110  Box Score        NaN    19911   NaN
# 417      Washington Wizards      113  Box Score        NaN    15124   NaN
# 418          Denver Nuggets      107  Box Score        NaN    19124   NaN
# 419              Miami Heat       92  Box Score        NaN    19901   NaN
# 420      Philadelphia 76ers       90  Box Score        NaN    15552   NaN
# 421         Toronto Raptors      103  Box Score        NaN    19800   NaN
# 422           Atlanta Hawks      107  Box Score        NaN    17575   NaN
# 423           Brooklyn Nets      118  Box Score         OT    15994   NaN
# 424       Charlotte Hornets       89  Box Score        NaN    19082   NaN
# 425     Cleveland Cavaliers       91  Box Score        NaN    20562   NaN
# 426   Golden State Warriors      103  Box Score        NaN    19596   NaN
# 427          Indiana Pacers      106  Box Score        NaN    18165   NaN
# 428      Los Angeles Lakers       85  Box Score        NaN    18997   NaN
# 429         Milwaukee Bucks      113  Box Score        NaN    15754   NaN
# 430  Minnesota Timberwolves       83  Box Score        NaN    16788   NaN
# 431    New Orleans Pelicans      115  Box Score        NaN    16686   NaN
# 432           Orlando Magic      104  Box Score        NaN    17061   NaN
# 433            Phoenix Suns       96  Box Score        NaN    17034   NaN
# 434      Washington Wizards      100  Box Score        NaN    15879   NaN
# 435   Golden State Warriors       89  Box Score        NaN    19596   NaN
# 436         Houston Rockets       88  Box Score        NaN    18319   NaN
# 437      Los Angeles Lakers       84  Box Score        NaN    18997   NaN
# 438              Miami Heat       94  Box Score         OT    19845   NaN
# 439   Oklahoma City Thunder       96  Box Score        NaN    18203   NaN
# 440           Atlanta Hawks      117  Box Score        NaN    19015   NaN
# 441           Brooklyn Nets       96  Box Score        NaN    17732   NaN
# 442       Charlotte Hornets       98  Box Score        NaN    19091   NaN
# 443        Dallas Mavericks      118  Box Score        NaN    20392   NaN
# 444         Detroit Pistons       93  Box Score        NaN    18288   NaN
# 445         Milwaukee Bucks       90  Box Score        NaN    16329   NaN
# 446  Minnesota Timberwolves       88  Box Score        NaN    15076   NaN
# 447    New Orleans Pelicans      110  Box Score        NaN    18248   NaN
# 448           Orlando Magic      101  Box Score        NaN    18846   NaN
# 449            Phoenix Suns      104  Box Score        NaN    17548   NaN
# 450  Portland Trail Blazers      105  Box Score        NaN    19393   NaN
#
#      HomeWin  HomeLastWin  VisitorLastWin  HomeTeamRanksHigher  \
# 400     True            0               0                    1
# 401     True            0               1                    1
# 402    False            0               1                    1
# 403     True            1               0                    1
# 404    False            0               0                    0
# 405     True            0               0                    0
# 406    False            1               1                    0
# 407    False            1               0                    0
# 408    False            1               0                    1
# 409     True            1               0                    1
# 410     True            0               1                    1
# 411    False            0               0                    1
# 412     True            1               0                    1
# 413    False            0               1                    1
# 414    False            1               0                    0
# 415     True            1               0                    1
# 416     True            1               0                    0
# 417     True            1               1                    1
# 418    False            0               0                    1
# 419    False            1               1                    1
# 420    False            0               1                    0
# 421     True            0               1                    0
# 422     True            1               1                    1
# 423    False            1               0                    0
# 424    False            0               1                    0
# 425     True            1               0                    1
# 426     True            1               1                    1
# 427    False            0               0                    1
# 428    False            1               1                    0
# 429     True            1               0                    1
# 430    False            0               1                    0
# 431     True            1               0                    0
# 432     True            1               1                    0
# 433    False            0               0                    1
# 434     True            1               1                    0
# 435     True            1               1                    1
# 436     True            0               1                    1
# 437    False            0               0                    0
# 438     True            0               1                    0
# 439    False            1               0                    0
# 440     True            1               0                    1
# 441    False            0               1                    0
# 442     True            0               0                    0
# 443     True            1               1                    0
# 444    False            0               1                    0
# 445    False            1               1                    0
# 446    False            0               0                    0
# 447     True            0               1                    0
# 448    False            1               1                    0
# 449    False            0               0                    1
# 450     True            0               0                    0
#
#      HomeTeamWonLast
# 400                0
# 401                0
# 402                0
# 403                1
# 404                1
# 405                0
# 406                0
# 407                0
# 408                0
# 409                0
# 410                0
# 411                1
# 412                0
# 413                0
# 414                0
# 415                0
# 416                0
# 417                0
# 418                1
# 419                0
# 420                0
# 421                1
# 422                0
# 423                0
# 424                0
# 425                1
# 426                1
# 427                0
# 428                0
# 429                1
# 430                0
# 431                0
# 432                0
# 433                1
# 434                0
# 435                0
# 436                0
# 437                0
# 438                0
# 439                0
# 440                1
# 441                0
# 442                1
# 443                0
# 444                1
# 445                0
# 446                0
# 447                0
# 448                0
# 449                0
# 450                0

# %%
X_lastwinner = dataset[[ "HomeTeamWonLast", "HomeTeamRanksHigher", "HomeLastWin", "VisitorLastWin",]].values
clf = DecisionTreeClassifier(random_state=14, criterion="entropy")

scores = cross_val_score(clf, X_lastwinner, y_true, scoring='accuracy',cv=3)

print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 62.2%

# %% [markdown]
# Accuracy has again improved by adding one more feature

# %%
############# experimenting with transformers 

## assigning numbers to teams instead of names
from sklearn.preprocessing import LabelEncoder
encoding = LabelEncoder()
encoding.fit(dataset["Home Team"].values)
home_teams = encoding.transform(dataset["Home Team"].values)
visitor_teams = encoding.transform(dataset["Visitor Team"].values)
home_teams
# Out:
# array([0, 4, 9, ..., 9, 5, 9])

# %%
X_teams = np.vstack([home_teams, visitor_teams]).T
X_teams
# Out:
# array([[ 0,  8],
#        [ 4,  5],
#        [ 9, 18],
#        ...,
#        [ 9,  5],
#        [ 5,  9],
#        [ 9,  5]])

# %%
# converting team names to categorical 
from sklearn.preprocessing import OneHotEncoder
onehot = OneHotEncoder(categories='auto')
X_teams = onehot.fit_transform(X_teams).todense()

clf = DecisionTreeClassifier(random_state=14)
scores = cross_val_score(clf, X_teams, y_true, scoring='accuracy',cv=3)
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 62.8%

# %% [markdown]
# #result is stil pretty same and only the team names were fed to model..hence not so reliable

# %% [markdown]
# # Using Random Forest to overcome possibilties of overfitting

# %% [markdown]
# In case of random forest, smaller trees are built using randomly selected smaller subset and also randomly selected features

# %%
#random forest 

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=14 , n_estimators = 10)
scores = cross_val_score(clf, X_teams, y_true, scoring='accuracy', cv=3)
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 65.3%

# %%
#with all the features
X_all = np.hstack([X_lastwinner, X_teams])
clf = RandomForestClassifier(random_state=14, n_estimators = 10)
scores = cross_val_score(clf, X_all, y_true, scoring='accuracy' , cv=3)
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 63.3%

# %%
#with estimators 250
X_all = np.hstack([X_lastwinner, X_teams])
clf = RandomForestClassifier(random_state=14, n_estimators=250)
scores = cross_val_score(clf, X_all, y_true, scoring='accuracy' , cv=3)
print("Accuracy: {0:.1f}%".format(np.mean(scores) * 100))
# Out:
# Accuracy: 64.5%

# %%
from sklearn.model_selection import GridSearchCV
parameter_space = {
    "max_features": [2, 10, 'auto'],
    "n_estimators": [100, 200],
    "criterion": ["gini", "entropy"],
    "min_samples_leaf": [2, 4, 6],
}

# %%
clf = RandomForestClassifier(random_state=14)
grid = GridSearchCV(clf, parameter_space , cv=3)
grid.fit(X_all, y_true)
print("Accuracy: {0:.1f}%".format(grid.best_score_ * 100))
# Out:
# Accuracy: 67.4%

# %%
print(grid.best_estimator_)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features=2, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=14, verbose=0, warm_start=False)

# %% [markdown]
# # Summary :
# Accuracies achieved :
# 1. Decision tree -
#
#   a. Features - if team had won previously - 59.4
#
#   b. Features - if team had won previously , which team has higher rankings , which team had won in previous encounter - 60.9
#
#
# 2. Rndom Forest -
#
#   a. Features - only team participating - 65.3
#
#   b. Features - All the previosuly derived features - 63.3
#
#   c. With increased estimators - 64.5
#
#   d. Using model selection of GridSearchCV - 67.4
